# %% [markdown]
# # [2819. 격자판의 숫자 이어 붙이기](https://swexpertacademy.com/main/code/problem/problemDetail.do?contestProbId=AV7I5fgqEogDFAXB)

# %% [markdown]
# ---

# %% [markdown]
# ## Memo
#
# - 4×4 , 여섯 번 이동
#
# - 만들 수 있는 서로 다른 일곱 자리 수들의 개수를 구하는 프로그램, cnt
#
# - 열 트리, 이때 열은 방향으로 설정, 이진트리 x
#
# - 종료조건, 1회시 마다 cnt, cnt n = cnt
#
# - 범위내 이동

# %% [markdown]
# ---

# %%
def dfs(n, string, ci, cj):
    
    
    
    # 1. 종료조건, 정답처리, set에 string을 추가후, main에서 len 처리 
    if n == 7:
        sset.add(string)
        return 
    
    
    # 2. 하부 처리, 4방향, 범위내 가능한 모든 경우 처리
    for di,dj in ((1,0),(-1,0),(0,1),(0,-1)):
        
        ni,nj = ci+di, cj+dj
            
        if 0<=ni<N and 0<=nj<N:
            
            dfs(n+1, string+arr[ni][nj], ni, nj)

# %%
T = int(input())


for t in range(1, T+1):
    
    N = 4
    arr = [ list(input().split()) for _ in range(N) ]    
    
    sset = set()
    

    # 임의의 방향에서 출발
    
    for si in range(0, N):
        
        for sj in range(0, N):
            
            dfs(1, arr[si][sj], si, sj)
    
    print(f'#{t} {len(sset)}')
# Out:
# 1
# 1 1 1 1
# 1 1 1 2
# 1 1 2 1
# 1 1 1 1
# #1 23

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
