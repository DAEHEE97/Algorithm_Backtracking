# %% [markdown]
# # [N과 M (1)_BT](https://www.acmicpc.net/problem/15649)
#
#
# - 자연수 N과 M이 주어졌을 때, 아래 조건을 만족하는 길이가 M인 수열

# %% [markdown]
# ---

# %% [markdown]
# ## 열 트리
#
# - n : 길이, 선택된 숫자의 개수
# - 가능한 모든 경우를 처리하면서, v 방문 처리 리스트를 만들어서, 방문한 적이 없으면 탐색 (단 중복 불가)

# %% [markdown]
# ---

# %%
def dfs(n, tlst):
        
    if n == M:

        ans.append(tlst)
    
        return
    
    
    # j, vlst, 0 ~ N-1까지 idx 
    for j in range(0, N):
        
        if v[j] == 0:
            
            v[j] = 1
            
            dfs(n+1, tlst + [lst[j]])
            
            v[j] = 0

# %%
N, M = map(int, input().split())

# 1 ~ N 까지, v = 1,2,3,4
# 0 ~ N-1 idx, 0,1,2,3
lst = list(range(1, N+1))


# 0,0,0,0 
# 0 1 2 3 중복 확인, 
v = [0] * (N)      

ans = []            

dfs(0, [])


for l in ans:
    
    print(*l)
# Out:
# 4 2
# 1 2
# 1 3
# 1 4
# 2 1
# 2 3
# 2 4
# 3 1
# 3 2
# 3 4
# 4 1
# 4 2
# 4 3

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ## permutations
#
# - 순열, n개중 서로 다른 m개를 선택

# %%
from itertools import permutations

N, M = map(int, input().split())

lst = list(range(1, N+1))

for tup in permutations(lst, M):
    
    print(*tup)
# Out:
# 4 2
# 1 2
# 1 3
# 1 4
# 2 1
# 2 3
# 2 4
# 3 1
# 3 2
# 3 4
# 4 1
# 4 2
# 4 3
